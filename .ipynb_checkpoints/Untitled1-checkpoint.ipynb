# %%
print('test 1')
# !git add .
# !git commit -m "test push 3"
# !git push
#aioerjfaoi;rej
# Out:
# test 1
# [main 1570f14] test push 3
#  2 files changed, 12 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  create mode 100644 Untitled1.ipynb
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 465 bytes | 465.00 KiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Greggy6767/PHYS481.git
#    35edb78..1570f14  main -> main
